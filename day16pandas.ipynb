# %% [markdown]
# # Pandas
# - Analyse 2D or multi data(but in the nack its just using nmpy)
# - Table like data

# %%
import pandas as pd
import requests

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 32],
    'City': ['New York', 'Paris', 'Berlin', 'London']
}

# %%
df = pd.DataFrame(data)
df
# Out:
#     Name  Age      City
# 0   John   28  New York
# 1   Anna   34     Paris
# 2  Peter   29    Berlin
# 3  Linda   32    London

# %%
#Filter columns
df['Name']
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: object

# %%
type(df)
type()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 type(df)
# ----> 2 type()
#
# TypeError: type() takes 1 or 3 arguments

# %%
#Filtering the rows using head
df.head(3)
# Out:
#     Name  Age      City
# 0   John   28  New York
# 1   Anna   34     Paris
# 2  Peter   29    Berlin

# %%
#Want to get the Feel of the data, to get the Infomation abou the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   City    4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 228.0+ bytes

# %%
print(df.shape)
#4 rows and 3 columns
#(4,1)
df.dtypes
df.columns
# Out:
# (4, 3)
# Index(['Name', 'Age', 'City'], dtype='object')

# %%
df.describe()
# Out:
#              Age
# count   4.000000
# mean   30.750000
# std     2.753785
# min    28.000000
# 25%    28.750000
# 50%    30.500000
# 75%    32.500000
# max    34.000000

# %%
tips_df = pd.read_csv("./tips.csv")
tips_df
10%4
# Out:
# 2
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
tips_df[['time','day','tip']]
# Out:
#        time   day   tip
# 0    Dinner   Sun  1.01
# 1    Dinner   Sun  1.66
# 2    Dinner   Sun  3.50
# 3    Dinner   Sun  3.31
# 4    Dinner   Sun  3.61
# ..      ...   ...   ...
# 239  Dinner   Sat  5.92
# 240  Dinner   Sat  2.00
# 241  Dinner   Sat  2.00
# 242  Dinner   Sat  1.75
# 243  Dinner  Thur  3.00
#
# [244 rows x 3 columns]

# %%
tipPp = tips_df['tip']/tips_df['size']
tips_df['tipPp'] = tipPp
tips_df.tail(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size     tipPp
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2  1.500000
# 235       10.07  1.25    Male     No   Sat  Dinner     2  0.625000
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2  0.500000
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2  0.585000
# 238       35.83  4.67  Female     No   Sat  Dinner     3  1.556667
# 239       29.03  5.92    Male     No   Sat  Dinner     3  1.973333
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  1.000000
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  1.000000
# 242       17.82  1.75    Male     No   Sat  Dinner     2  0.875000
# 243       18.78  3.00  Female     No  Thur  Dinner     2  1.500000

# %%
#How much % peopl are tipping
tipPercent = (tips_df['tip']/tips_df['total_bill'])*100
tips_df['tipPercent '] = round(tipPercent,2) 
tips_df.tail(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size     tipPp  \
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2  1.500000
# 235       10.07  1.25    Male     No   Sat  Dinner     2  0.625000
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2  0.500000
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2  0.585000
# 238       35.83  4.67  Female     No   Sat  Dinner     3  1.556667
# 239       29.03  5.92    Male     No   Sat  Dinner     3  1.973333
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  1.000000
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  1.000000
# 242       17.82  1.75    Male     No   Sat  Dinner     2  0.875000
# 243       18.78  3.00  Female     No  Thur  Dinner     2  1.500000
#
#      tipPercent
# 234        19.32
# 235        12.41
# 236         7.94
# 237         3.56
# 238        13.03
# 239        20.39
# 240         7.36
# 241         8.82
# 242         9.82
# 243        15.97

# %% [markdown]
# ## Sorting and Stuff

# %%
tips_df.sort_values(by='total_bill',ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size     tipPp  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3  3.333333
# 212       48.33   9.00    Male     No   Sat  Dinner     4  2.250000
# 59        48.27   6.73    Male     No   Sat  Dinner     4  1.682500
# 156       48.17   5.00    Male     No   Sun  Dinner     6  0.833333
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3  1.166667
# ..          ...    ...     ...    ...   ...     ...   ...       ...
# 149        7.51   2.00    Male     No  Thur   Lunch     2  1.000000
# 111        7.25   1.00  Female     No   Sat  Dinner     1  1.000000
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2  2.575000
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2  0.500000
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1  1.000000
#
#      tipPercent
# 170        19.68
# 212        18.62
# 59         13.94
# 156        10.38
# 182         7.72
# ..           ...
# 149        26.63
# ...

# %%
#Filter the items of only on sunday
tips_df[tips_df['day']=='Sun']
# Out:
#      total_bill   tip     sex smoker  day    time  size     tipPp  tipPercent
# 0         16.99  1.01  Female     No  Sun  Dinner     2  0.505000         5.94
# 1         10.34  1.66    Male     No  Sun  Dinner     3  0.553333        16.05
# 2         21.01  3.50    Male     No  Sun  Dinner     3  1.166667        16.66
# 3         23.68  3.31    Male     No  Sun  Dinner     2  1.655000        13.98
# 4         24.59  3.61  Female     No  Sun  Dinner     4  0.902500        14.68
# ..          ...   ...     ...    ...  ...     ...   ...       ...          ...
# 186       20.90  3.50  Female    Yes  Sun  Dinner     3  1.166667        16.75
# 187       30.46  2.00    Male    Yes  Sun  Dinner     5  0.400000         6.57
# 188       18.15  3.50  Female    Yes  Sun  Dinner     3  1.166667        19.28
# 189       23.10  4.00    Male    Yes  Sun  Dinner     3  1.333333        17.32
# 190       15.69  1.50    Male    Yes  Sun  Dinner     2  0.750000         9.56
#
# [76 rows x 9 columns]

# %%
#Get the rows where person's have tipped more than R10
tipsFri = tips_df[tips_df['day']=='Fri'][tips_df['tip']>3]
tipsFri.sort_values(by='tip',ascending=False).head(5)
# Out:
# C:\Users\e1005282\AppData\Local\Temp\ipykernel_6332\4249892542.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tipsFri = tips_df[tips_df['day']=='Fri'][tips_df['tip']>3]
#      total_bill   tip     sex smoker  day    time  size   tipPp  tipPercent
# 95        40.17  4.73    Male    Yes  Fri  Dinner     4  1.1825        11.77
# 93        16.32  4.30  Female    Yes  Fri  Dinner     2  2.1500        26.35
# 96        27.28  4.00    Male    Yes  Fri  Dinner     2  2.0000        14.66
# 91        22.49  3.50    Male     No  Fri  Dinner     2  1.7500        15.56
# 221       13.42  3.48  Female    Yes  Fri   Lunch     2  1.7400        25.93

# %%
##Task 04
#Large parties, people are 5 or R35

tipsFri = tips_df[(tips_df['size']>=5)|(tips_df['total_bill']>=35)]
tipsFri
# Out:
#      total_bill    tip     sex smoker   day    time  size     tipPp  \
# 11        35.26   5.00  Female     No   Sun  Dinner     4  1.250000
# 23        39.42   7.58    Male     No   Sat  Dinner     4  1.895000
# 56        38.01   3.00    Male    Yes   Sat  Dinner     4  0.750000
# 59        48.27   6.73    Male     No   Sat  Dinner     4  1.682500
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4  1.182500
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3  0.833333
# 112       38.07   4.00    Male     No   Sun  Dinner     3  1.333333
# 125       29.80   4.20  Female     No  Thur   Lunch     6  0.700000
# 141       34.30   6.70    Male     No  Thur   Lunch     6  1.116667
# 142       41.19   5.00    Male     No  Thur   Lunch     5  1.000000
# 143       27.05   5.00  Female     No  Thur   Lunch     6  0.833333
# 155       29.85   5.14  Female     No   Sun  Dinner     5  1.028000
# 156       48.17   5.00    Male     No   Sun  Dinner     6  0.833333
# ...

# %%
print(tips_df['day'].value_counts())
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %% [markdown]
# ## Summary
# - Filter row and colum
# -

# %% [markdown]
# ## Slicing
# - loc
# - iloc -indexing
# ##### What is the difference though
# - tips_df.loc[3:5] will give all 3,4,5

# %%
tips_df.iloc[3]#['tip']
#You'll get the thirsd value in the row
#0,1,2,3...
# Out:
# total_bill      23.68
# tip              3.31
# sex              Male
# smoker             No
# day               Sun
# time           Dinner
# size                2
# tipPp           1.655
# tipPercent      13.98
# Name: 3, dtype: object

# %%
tips_df.iloc[3:5]
# Out:
#    total_bill   tip     sex smoker  day    time  size   tipPp  tipPercent
# 3       23.68  3.31    Male     No  Sun  Dinner     2  1.6550        13.98
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.9025        14.68

# %%
tips_df.loc[3:5]
# Out:
#    total_bill   tip     sex smoker  day    time  size   tipPp  tipPercent
# 3       23.68  3.31    Male     No  Sun  Dinner     2  1.6550        13.98
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.9025        14.68
# 5       25.29  4.71    Male     No  Sun  Dinner     4  1.1775        18.62

# %%
#tips_df.tail(10).loc[3:5]
#Will give us an eeror becuase hauwa

# %%
tips_df.tail(10).iloc[3:5]
#this onw will not error out
# Out:
#      total_bill   tip     sex smoker  day    time  size     tipPp  tipPercent
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2  0.585000         3.56
# 238       35.83  4.67  Female     No  Sat  Dinner     3  1.556667        13.03

# %%
tips_df.loc[3:5,'tip']
# Out:
# 3    3.31
# 4    3.61
# 5    4.71
# Name: tip, dtype: float64

# %%
#(x,y----being the columns that we are wokrnig with)
tips_df.loc[3:5,'tip':'smoker']
# Out:
#     tip     sex smoker
# 3  3.31    Male     No
# 4  3.61  Female     No
# 5  4.71    Male     No

# %% [markdown]
# So it will work differecntly with iloc as it give me erros
# i-locate use the index to find it, so woth the coulmn wil use the actual index

# %%
tips_df.iloc[3:5,1:4]
# Out:
#     tip     sex smoker
# 3  3.31    Male     No
# 4  3.61  Female     No

# %% [markdown]
# # Task

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size     tipPp  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2  0.505000
# 1         10.34  1.66    Male     No   Sun  Dinner     3  0.553333
# 2         21.01  3.50    Male     No   Sun  Dinner     3  1.166667
# 3         23.68  3.31    Male     No   Sun  Dinner     2  1.655000
# 4         24.59  3.61  Female     No   Sun  Dinner     4  0.902500
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  1.973333
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  1.000000
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  1.000000
# 242       17.82  1.75    Male     No   Sat  Dinner     2  0.875000
# 243       18.78  3.00  Female     No  Thur  Dinner     2  1.500000
#
#      tipPercent
# 0           5.94
# 1          16.05
# 2          16.66
# 3          13.98
# 4          14.68
# ..           ...
# 239        20.39
# ...

# %% [markdown]
# Find the rows with highest tip_persent, skipp the first first on weekend(sat & Sun)

# %%
#Order by tip_percent
tip_Percent = tips_df.sort_values(by='tipPp',ascending=False)
tip_Weekend = tip_Percent[(tip_Percent['day']=='Sun')|(tip_Percent['day']=='Sat')]
v = tip_Weekend.iloc[5:]
v.loc[:, ['day', 'tip', 'total_bill']]
# Out:
#      day   tip  total_bill
# 212  Sat  9.00       48.33
# 214  Sat  6.50       28.17
# 28   Sat  4.30       21.70
# 107  Sat  4.29       25.21
# 104  Sat  4.08       20.92
# ..   ...   ...         ...
# 230  Sat  2.00       24.01
# 153  Sun  2.00       24.55
# 159  Sun  2.00       16.49
# 154  Sun  2.00       19.77
# 187  Sun  2.00       30.46
#
# [158 rows x 3 columns]

# %%
column = tips_df.tail(6).iloc[2:4,1:5]
column
# Out:
# Empty DataFrame
# Columns: [tip, sex, smoker, day]
# Index: []

# %% [markdown]
# ## Summarizing

# %%
#Getting your mean and 
tips_df['tip'].mean()
# .median() .sum() .mode()
# Out:
# 2.99827868852459

# %% [markdown]
# Now we want to do it some specific colums, in one table

# %%
tips_df[['tip','total_bill']].mean()
# Out:
# tip            2.998279
# total_bill    19.785943
# dtype: float64

# %% [markdown]
# ### Group by

# %% [markdown]
# Average total bill on any day that you take
# - So like Average for Sunday or Wed
# ```sql
# Select average(total_bill)
# from tips_df
# group by day
# ```

# %%
tips_df.groupby('day')['total_bill'].mean()
# Out:
# day
# Fri     17.151579
# Sat     20.441379
# Sun     21.410000
# Thur    17.682742
# Name: total_bill, dtype: float64

# %% [markdown]
# Who is leaving more tips between smokers

# %%
tips_df.groupby('smoker')['tip'].mean()
# Out:
# smoker
# No     2.991854
# Yes    3.008710
# Name: tip, dtype: float64

# %%
tips_df.groupby('smoker')['tip'].sum()
# Out:
# smoker
# No     451.77
# Yes    279.81
# Name: tip, dtype: float64

# %% [markdown]
# #### Task 03

# %%
tips_df.groupby('day').aggregate({'total_bill':'sum','tip':'mean'})
# Out:
#       total_bill       tip
# day
# Fri       325.88  2.734737
# Sat      1778.40  2.993103
# Sun      1627.16  3.255132
# Thur     1096.33  2.771452

# %% [markdown]
# # One More level of drilling

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size     tipPp  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2  0.505000
# 1         10.34  1.66    Male     No   Sun  Dinner     3  0.553333
# 2         21.01  3.50    Male     No   Sun  Dinner     3  1.166667
# 3         23.68  3.31    Male     No   Sun  Dinner     2  1.655000
# 4         24.59  3.61  Female     No   Sun  Dinner     4  0.902500
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  1.973333
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  1.000000
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  1.000000
# 242       17.82  1.75    Male     No   Sat  Dinner     2  0.875000
# 243       18.78  3.00  Female     No  Thur  Dinner     2  1.500000
#
#      tipPercent
# 0           5.94
# 1          16.05
# 2          16.66
# 3          13.98
# 4          14.68
# ..           ...
# 239        20.39
# ...

# %%
#The order will matter in terms of the stuff that happend here
tips_df.groupby(['smoker','day'])['tip'].sum()
# Out:
# smoker  day
# No      Fri      11.25
#         Sat     139.63
#         Sun     180.57
#         Thur    120.32
# Yes     Fri      40.71
#         Sat     120.77
#         Sun      66.82
#         Thur     51.51
# Name: tip, dtype: float64

# %% [markdown]
# #### Task who earns more tip each day

# %%
#The order will matter in terms of the stuff that happend here
tips_df.groupby(['day','sex'])['tip'].mean().unstack()
# Out:
# sex     Female      Male
# day
# Fri   2.781111  2.693000
# Sat   2.801786  3.083898
# Sun   3.367222  3.220345
# Thur  2.575625  2.980333

# %% [markdown]
# ##Task
# max min and who earns more in each day

# %%
toCSV = tips_df.groupby(['day','sex']).aggregate({'tip':['max','min']}).unstack()
toCSV.to_csv("./group.csv")

# %% [markdown]
# ### Pivot Tables

# %%
pd.pivot_table(tips_df,index='day',columns='smoker',values='tip',aggfunc='sum')
# Out:
# smoker      No     Yes
# day
# Fri      11.25   40.71
# Sat     139.63  120.77
# Sun     180.57   66.82
# Thur    120.32   51.51

# %% [markdown]
# # Visualize
# - Matplot
# - Seaborn
#     - Uses internally Matplot
#     - Complex Visualisation easily

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Bar Graph
# Average Total bill by each day

# %%
x_days = tips_df['day'].unique()

y_avg = tips_df.groupby('day')['total_bill'].mean()

plt.bar(x_days,y_avg,color="pink",alpha=0.5)
plt.xlabel("Days")
plt.ylabel("Average Sales in R")
plt.title("Average Sales In the Week")
# Out:
# Text(0.5, 1.0, 'Average Sales In the Week')

# %%
y_avg = tips_df.groupby('day')['total_bill'].mean()
x_days = y_avg.index

y_avg.plot(kind="bar", xlabel="Days", ylabel="Average sales in R", title="Average sales in the week", color="crimson",  alpha=0.2)
# Out:
# <Axes: title={'center': 'Average sales in the week'}, xlabel='Days', ylabel='Average sales in R'>

# %%
y_avg = tips_df.groupby('day')['total_bill'].mean()
x_days = y_avg.index

y_avg.plot(kind="pie", autopct='%1.1f%%', title="Average sales in the week")

# %% [markdown]
# ## Task
# Create a pie chart

# %%
y_axis = tips_df.groupby('time')['time'].count()
x_axis = y_axis.index
y_axis.plot(kind="pie", autopct='%1.1f%%', title="Propotion of meals")
# Out:
# <Axes: title={'center': 'Propotion of meals'}, ylabel='time'>

# %%
plt.scatter(tips_df['total_bill'],tips_df['tips'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\e1005282\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tips'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[178], line 1
# ...

# %% [markdown]
# Ticket Size
#
# Total_bill _> x-axis
# Frequency is your Y-axis

# %%
plt.hist(tips_df['total_bill'],color='red',bins=100)
# Out:
# (array([ 1.,  0.,  0.,  0.,  0.,  1.,  0.,  0.,  2.,  3.,  0.,  5.,  0.,
#          3.,  5., 10.,  3.,  5.,  4.,  7.,  8., 10.,  4.,  6.,  3.,  7.,
#          6., 11.,  6.,  7.,  7., 10.,  6.,  1.,  4.,  4.,  9.,  6.,  2.,
#          2.,  3.,  5.,  2.,  4.,  4.,  3.,  3.,  3.,  1.,  3.,  4.,  0.,
#          2.,  2.,  2.,  1.,  4.,  2.,  0.,  2.,  1.,  1.,  3.,  0.,  0.,
#          1.,  4.,  1.,  1.,  0.,  0.,  0.,  0.,  2.,  1.,  0.,  1.,  1.,
#          1.,  1.,  0.,  0.,  0.,  1.,  0.,  0.,  1.,  0.,  1.,  0.,  0.,
#          0.,  0.,  0.,  3.,  0.,  0.,  0.,  0.,  1.]),
#  array([ 3.07  ,  3.5474,  4.0248,  4.5022,  4.9796,  5.457 ,  5.9344,
#          6.4118,  6.8892,  7.3666,  7.844 ,  8.3214,  8.7988,  9.2762,
#          9.7536, 10.231 , 10.7084, 11.1858, 11.6632, 12.1406, 12.618 ,
#         13.0954, 13.5728, 14.0502, 14.5276, 15.005 , 15.4824, 15.9598,
#         16.4372, 16.9146, 17.392 , 17.8694, 18.3468, 18.8242, 19.3016,
# ...

# %%
# x-> day
# y -> total bill
sns.barplot(x='day',y='total_bill',data=tips_df)
#In defualt its gonna give us average
sns.barplot(x='day',y='total_bill',data=tips_df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.regplot(y='tip',x='total_bill',data=tips_df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
plt.show()
